# %% [markdown]
# # Project 2 Code

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import datetime

warnings.filterwarnings("ignore")

# %%
# Reading the data
data = pd.read_excel('../../data/market_data.xlsx')

# %%
# Information about the data
data.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63457 entries, 0 to 63456
# Data columns (total 13 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Time (UTC+10)                                           63457 non-null  datetime64[ns]
#  1   Regions NSW Trading Price ($/MWh)                       63457 non-null  float64
#  2   Regions SA Trading Price ($/MWh)                        63457 non-null  float64
#  3   Regions TAS Trading Price ($/MWh)                       63457 non-null  float64
#  4   Regions VIC Trading Price ($/MWh)                       63457 non-null  float64
#  5   Regions NSW Trading Total Intermittent Generation (MW)  63457 non-null  float64
#  6   Regions SA Trading Total Intermittent Generation (MW)   63457 non-null  float64
#  7   Regions TAS Trading Total Intermittent Generation (MW)  63457 non-null  float64
# ...

# %%
# Filtering for required data (Victoria only)
data_vic = data[['Time (UTC+10)',
                 'Regions VIC Trading Price ($/MWh)', 
                 'Regions VIC Trading Total Intermittent Generation (MW)', 
                 'Regions VIC Operational Demand (MW)']]

# %%
# Sample (for my reference)
data_vic.head()
# Out:
#         Time (UTC+10)  Regions VIC Trading Price ($/MWh)  \
# 0 2018-01-01 00:00:00                              90.43
# 1 2018-01-01 00:30:00                              92.46
# 2 2018-01-01 01:00:00                              87.62
# 3 2018-01-01 01:30:00                              73.08
# 4 2018-01-01 02:00:00                              70.18
#
#    Regions VIC Trading Total Intermittent Generation (MW)  \
# 0                                             146.87
# 1                                             131.68
# 2                                             119.98
# 3                                             123.86
# 4                                             132.72
#
#    Regions VIC Operational Demand (MW)
# 0                                 4599
# 1                                 4398
# 2                                 4238
# 3                                 4112
# 4                                 3956

# %%
# Statistical information
data_vic.describe()
# Out:
#        Regions VIC Trading Price ($/MWh)  \
# count                       63457.000000
# mean                           78.746880
# std                           289.259796
# min                          -676.370000
# 25%                            39.010000
# 50%                            64.110000
# 75%                            94.850000
# max                         14700.000000
#
#        Regions VIC Trading Total Intermittent Generation (MW)  \
# count                                       63457.000000
# mean                                          169.029236
# std                                           114.763946
# min                                            -0.860000
# 25%                                            70.080000
# 50%                                           152.060000
# 75%                                           257.320000
# max                                           467.480000
#
#        Regions VIC Operational Demand (MW)
# ...

# %% [markdown]
# ### Talking Points:
# - Negative prices (minimum)
# - Preprocessing
# - Re-calculation

# %% [markdown]
# # Checking for Correlation

# %%
# Seaborn correlation heatmap
sns.heatmap(data_vic.corr(), annot = True)
plt.title('Correlation Heatmap')
plt.savefig("correlation.png", bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ### Talking Points:
# - Correlation (little)
# - Independent

# %% [markdown]
# # Time Analysis (for VIC Data)

# %%
plt.plot(data_vic['Time (UTC+10)'], data_vic['Regions VIC Trading Price ($/MWh)'])
plt.show()

# %%
plt.plot(data_vic['Time (UTC+10)'], data_vic['Regions VIC Operational Demand (MW)'])
plt.show()

# %%
plt.plot(data_vic['Time (UTC+10)'], data_vic['Regions VIC Trading Total Intermittent Generation (MW)'])
plt.show()

# %% [markdown]
# ### Talking Points:
# - Peaks (G1 & G2 Similar)
